# %%
import torch

# %%
a = torch.tensor([1, 0, 0, 1])
torch.mode(a)
# Out:
# torch.return_types.mode(
# values=tensor(0),
# indices=tensor(2))

# %%
values, indexes = torch.sort(a)
indexes[int(0.5*len(a)) - 1]
# Out:
# tensor(2)

# %%
values
# Out:
# tensor([0, 0, 1, 1])
